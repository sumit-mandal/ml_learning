# %%
import numpy as np 
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense 
from keras.optimizers import Adam

# %%
np.random.seed(0)

# %%
points = 500
X = np.linspace(-3,3,points)
#Return evenly spaced numbers over a specified interval.
y = np.sin(X) + np.random.uniform(-0.5,0.5,points)

#adding some noise to our points so that each point in this curve can deviate from its standard shape
#using np.random.uniform we'll add variance in our graph. To make our model more compex.
#And this variance we'll have is just that for every point it's vertical value y is going to vertically shift in a range of -0.5 up until 0.5 units from the curve 
# and we do this for every y value. 

plt.scatter(X,y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid',input_dim=1))
#input_dim means input nodes

#hidden layer
model.add(Dense(30,activation='sigmoid'))
#30 nodes

#output layer
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse',optimizer=adam)
#mean squared error

#We calculate the standard error of the estimate the mean square error 
#the standard error of the estimate is a measure of the accuracy of the models prediction.
model.fit(X,y,epochs=50)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 1ms/step - loss: 0.5818
# Epoch 2/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2632
# Epoch 3/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2537
# Epoch 4/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2601
# Epoch 5/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2301
# Epoch 6/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2222
# Epoch 7/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2322
# Epoch 8/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2094
# Epoch 9/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2187
# Epoch 10/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2107
# Epoch 11/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1862
# Epoch 12/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1689
# Epoch 13/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1825
# Epoch 14/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1735
# Epoch 15/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1534
# Epoch 16/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1335
# Epoch 17/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1295
# Epoch 18/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1382
# Epoch 19/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1324
# Epoch 20/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1180
# Epoch 21/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1237
# Epoch 22/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1131
# Epoch 23/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1156
# Epoch 24/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1059
# Epoch 25/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1053
# Epoch 26/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1030
# Epoch 27/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1119
# Epoch 28/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1125
# Epoch 29/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1133
# Epoch 30/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1067
# Epoch 31/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1097
# Epoch 32/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1149
# Epoch 33/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1077
# Epoch 34/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1085
# Epoch 35/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1069
# Epoch 36/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1095
# Epoch 37/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1195
# Epoch 38/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1040
# Epoch 39/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1010
# Epoch 40/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1036
# Epoch 41/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1070
# Epoch 42/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1048
# Epoch 43/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1007
# Epoch 44/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1020
# Epoch 45/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1024
# Epoch 46/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1032
# Epoch 47/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1199
# Epoch 48/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0912
# Epoch 49/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1014
# Epoch 50/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1066

# %%
prediction = model.predict(X)
plt.scatter(X,y)
plt.plot(X,prediction,'ro')
#for each estimated value,ro is shown as red colored circle
plt.show()
